# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarita821patil/Projects/blob/main/Sarita_CodeAlpha_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK 3

# %% [markdown]
# # Sales Prediction using Python

# %% [markdown]
# Sales prediction means predicting how much of a product people will buy based on
# factors
# such as the amount you spend to advertise your product, the segment of people you
# advertise for, or the platform you are advertising on about your product.
# Typically, a product and service-based business always need their Data Scientist to
# predict
# their future sales with every step they take to manipulate the cost of advertising their
# product. So let’s start the task of sales prediction with machine learning using Python.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset (ensure this is done before any operation on the data)
data = pd.read_csv('/content/Advertising.csv')

# Check for missing values
print("Missing values in each column:")
print(data.isnull().sum())
print("\n")

# Basic statistics of the dataset
print("Basic statistics of the dataset:")
print(data.describe())
print("\n")

# Plotting the relationships between features and target variable (Sales)
sns.pairplot(data, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.suptitle('Pairplot between Advertising Channels and Sales', y=1.02)
plt.show()

# Plot heatmap of correlation between variables
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title('Correlation Matrix of Advertising Data')
plt.show()
# Out:
# Missing values in each column:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64
#
#
# Basic statistics of the dataset:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000
